# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.comhttps:/github.com/webbmaps/geog-510-test/blob/main/.ipynb_checkpoints/odds_evens-checkpoint.ipynb

# %%
# 1. Get the input and turn the text into a number
year = int(input('Birth Year? '))

# 2. Check if the remainder of year / 2 is zero
if year % 2 == 0:
    print('Even steven')
else:
    print('Oddball')
